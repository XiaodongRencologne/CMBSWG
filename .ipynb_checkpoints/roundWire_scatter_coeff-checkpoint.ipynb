# %%
import numpy as np
from scipy.special import jv,jvp,hankel2,h2vp
import matplotlib.pyplot as plt

N = 10

# %%
def sigma_E(wavelength,a,phi):
    k = 2*np.pi/wavelength
    z=0
    for n in np.linspace(-N,N,2*N+1):
        z += jv(n,k*a)/hankel2(n,k*a)*np.exp(-1j*n*(phi-np.pi))
    return 4/k*np.abs(z)**2

def sigma_H(wavelength,a,phi):
    k = 2*np.pi/wavelength
    z=0
    for n in np.linspace(-N,N,2*N+1):
        z += jvp(n,k*a)/h2vp(n,k*a) * np.exp(-1j*n*(phi-np.pi))
    return 4/k*np.abs(z)**2

def sigma_E_t(wavelength,a):
    phi = np.linspace(np.pi/2,3/2*np.pi,10001)
    dp = phi[1]-phi[0]
    w = np.ones(phi.size)
    w[0]=1/2
    w[-1]=1/2
    w = w*dp
    k = 2*np.pi/wavelength
    z=0
    for n in np.linspace(-N,N,2*N+1):
        z += jv(n,k*a)/hankel2(n,k*a)*np.exp(-1j*n*(phi-np.pi))
    return 2/np.pi/k*(w*np.abs(z)**2).sum(axis = 1)

def sigma_H_t(wavelength,a):
    phi = np.linspace(np.pi/2,3/2*np.pi,10001)
    dp = phi[1]-phi[0]
    w = np.ones(phi.size)
    w[0]=1/2
    w[-1]=1/2
    w = w*dp
    k = 2*np.pi/wavelength
    z=0
    for n in np.linspace(-N,N,2*N+1):
        z += jvp(n,k*a)/h2vp(n,k*a) * np.exp(-1j*n*(phi-np.pi))
    return 2/np.pi/k*(w*np.abs(z)**2).sum(axis = 1)

# %%
def E_polar_co(wavelength,a,phi):
    k = np.pi*2/wavelength
    z = 0
    for n in np.linspace(-N,N,2*N+1):
        z += jv(n,k*a)/hankel2(n,k*a) * np.exp(-1j*n*(phi-np.pi))
    return z #*np.sqrt(2/np.pi/k)*np.exp(1j*np.pi/4)

def H_polar_co(wavelength,a,phi):
    k = np.pi*2/wavelength
    z=0
    for n in np.linspace(-N,N,2*N+1):
        z += jvp(n,k*a)/h2vp(n,k*a) * np.exp(-1j*n*(phi-np.pi))
    return z #*np.sqrt(2/np.pi/k)*np.exp(1j*np.pi/4)

# %% [markdown]
# ## 1. scatter coefficient vs scattering angle, at different wavelength
#  * diameter of the wire, a = 0.127
#  * wire spacing, L = 600

# %%
Lambda1 = [1,3.33,10] #mm
a = 0.127
#L=600
co_E = {}
co_H = {}
Phi = np.linspace(0,np.pi,1001)
for wave in Lambda1:
    K = 2*np.pi/wave
    co_E[str(wave)] = E_polar_co(wave,a,Phi)
    co_H[str(wave)] = H_polar_co(wave,a,Phi)

fig = plt.figure(figsize = (8,5))
for key in co_E:
    plt.plot(Phi*180/np.pi,np.abs(co_E[key])**2,label ='$\lambda$='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scatter coefficient',fontsize=15)
plt.xlabel('scatter angle (degrees)',fontsize=15)
plt.title('E-polarization, Wire thickness '+str(a*2)+'mm',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([0,180])
plt.show()

fig = plt.figure(figsize = (8,5))
for key in co_H:
    plt.plot(Phi*180/np.pi,np.abs(co_H[key])**2,label ='$\lambda$='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scatter coefficient',fontsize=15)
plt.xlabel('scatter angle (degrees)',fontsize=15)
plt.title('H-polarization, Wire thickness '+str(a*2)+'mm',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([0,180])
plt.show()

# %% [markdown]
# ## 2. scatter cross section vs scattering angle, at different wavelength
#  * diameter of the wire, a = 0.127
#  * wire spacing, L = 600

# %%
Lambda1 = [1,3.33,10] #mm
a = 0.3#0.127
L=600
A_E = {}
A_H = {}
Phi = np.linspace(0,np.pi,1001)
for wave in Lambda1:
    K = 2*np.pi/wave
    A_E[str(wave)] = sigma_E(wave,a,Phi)
    A_H[str(wave)] = sigma_H(wave,a,Phi)

fig = plt.figure(figsize = (8,5))
for key in A_E:
    plt.plot(Phi*180/np.pi,np.abs(A_E[key]),label ='$\lambda$='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scatter width $\sigma_E$ /mm',fontsize=15)
plt.xlabel('scatter angle (degrees)',fontsize=15)
plt.title('E-polarization, Wire diameter '+str(a*2)+'mm',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([0,180])
plt.savefig('scater_width_E_polar.png')
plt.show()

fig = plt.figure(figsize = (8,5))
for key in A_H:
    plt.plot(Phi*180/np.pi,np.abs(A_H[key]),label ='$\lambda$='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scatter width $\sigma_H$ /mm',fontsize=15)
plt.xlabel('scatter angle (degrees)',fontsize=15)
plt.title('H-polarization, Wire diameter '+str(a*2)+'mm',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([0,180])
plt.savefig('scater_width_H_polar.png')
plt.show()

# %%
Phi = np.linspace(0,2*np.pi,4001)
wave = 3.33103#mm
a = 0.127 #mm
D = sigma_E(wave,a,Phi)
w= np.ones(Phi.size)
w[0]=1/2
w[-1]=1/2
d_p = (Phi[1]-Phi[0]) * w
print((D*d_p).sum()/2/np.pi)
print(sigma_E_t(wave,a))
# Out:
# 1.0954715605398333
# 0.6072055776474918

# %% [markdown]
# ## 3. Scattering Fraction for a set of wires with different wire spacing

# %%
wave = 3.33#mm #mm
a = np.linspace(0.025,1,101).reshape(-1,1)
spacing = [100,200,300,600]
F_E = {}
F_H = {}
Phi = np.linspace(0,2*np.pi,1001)
d_p = Phi[1]-Phi[0]
for L in spacing:
    K = 2*np.pi/wave
    F_E[str(L)] = sigma_E_t(wave,a/2)#/L
    F_H[str(L)] = sigma_H_t(wave,a/2)#/L

fig = plt.figure(figsize = (8,5))
for key in F_E:
    plt.plot(a,np.abs(F_E[key]),label ='Wire space='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scattering Fraction %',fontsize=15)
plt.xlabel('Wire diameter mm',fontsize=15)
plt.title('E-polarization, $\lambda = 3.33mm (90GHz)$',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.show()

fig = plt.figure(figsize = (8,5))
for key in F_H:
    plt.plot(a,np.abs(F_H[key]),label ='Wire space='+ key+'mm')
plt.legend(fontsize= 13)
plt.ylabel('Scattering Fraction %',fontsize=15)
plt.xlabel('Wire diameter mm',fontsize=15)
plt.title('H-polarization, $\lambda = 3.33mm (90GHz)$',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.show()

print(F_E['300'][24]*10*1000)
# Out:
# 6167.988876090199

# %%
wave = 3.33#mm #mm
a = np.linspace(0.025,1,101).reshape(-1,1)
spacing = [100,200,300,600]
F_E = {}
F_H = {}
Phi = np.linspace(0,2*np.pi,1001)
d_p = Phi[1]-Phi[0]
for L in spacing:
    K = 2*np.pi/wave
    F_E[str(L)] = (sigma_E(wave,a/2,Phi)*d_p).sum(axis=1)/L
    F_H[str(L)] = (sigma_H(wave,a/2,Phi)*d_p).sum(axis=1)/L

fig = plt.figure(figsize = (8,5))
for key in F_E:
    plt.plot(a,np.abs(F_E[key])*100,label ='Wire space='+ key+'mm')
plt.legend(fontsize= 15)
plt.ylabel('Scattering Fraction %',fontsize=15)
plt.xlabel('Wire diameter mm',fontsize=15)
plt.title('E-polarization, $\lambda = 3.33mm (90GHz)$',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.show()

fig = plt.figure(figsize = (8,5))
for key in F_H:
    plt.plot(a,np.abs(F_H[key])*100,label ='Wire space='+ key+'mm')
plt.legend(fontsize= 13)
plt.ylabel('Scattering Fraction %',fontsize=15)
plt.xlabel('Wire diameter mm',fontsize=15)
plt.title('H-polarization, $\lambda = 3.33mm (90GHz)$',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.show()

print(F_E['300'][24]*10*1000)
# Out:
# 232.6565658155427

# %%
(sigma_E(wave,0.127/2,Phi)*d_p).sum()/600
# Out:
# np.float64(0.007356143639021071)

# %%
Lambdas = [1,3.33]#mm #mm
a = np.linspace(25,500,101).reshape(-1,1)
spacing = [100,200,300,600]
F_E = {}
F_H = {}
Phi = np.linspace(0,2*np.pi,1001)
d_p = Phi[1]-Phi[0]
for wave in Lambdas:
    F_E[str(wave)] = {}
    F_H[str(wave)] = {}
    for L in spacing:
        K = 2*np.pi/wave
        F_E[str(wave)][str(L)] = (sigma_E(wave,a/1000/2,Phi)*d_p).sum(axis=1)/L
        F_H[str(wave)][str(L)] = (sigma_H(wave,a/1000/2,Phi)*d_p).sum(axis=1)/L

fig = plt.figure(figsize = (8,5))
lines=['-','--',':','-.']
colors = ['k','blue','orange']

key='1'
plt.plot(a,np.abs(F_E[key]['100'])*100,linestyle=lines[0],color=colors[0],label ='Wire space= 100mm (N=61)')
plt.plot(a,np.abs(F_E[key]['200'])*100,linestyle=lines[1],color=colors[0],label ='Wire space= 200mm (N=31)')
plt.plot(a,np.abs(F_E[key]['300'])*100,linestyle=lines[2],color=colors[0],label ='Wire space= 300mm (N=21)')
plt.plot(a,np.abs(F_E[key]['600'])*100,linestyle=lines[3],color=colors[0],label ='Wire space= 600mm (N=11)')
key = '3.33'
plt.plot(a,np.abs(F_E[key]['100'])*100,linestyle=lines[0],color=colors[1],)#label ='Wire space= 100mm (N=61)')
plt.plot(a,np.abs(F_E[key]['200'])*100,linestyle=lines[1],color=colors[1],)#label ='Wire space= 200mm (N=31)')
plt.plot(a,np.abs(F_E[key]['300'])*100,linestyle=lines[2],color=colors[1],)#label ='Wire space= 300mm (N=21)')
plt.plot(a,np.abs(F_E[key]['600'])*100,linestyle=lines[3],color=colors[1],)#label ='Wire space= 600mm (N=11)')

plt.legend(fontsize= 10)
#plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.ylabel('Scatter Fraction (%)',fontsize=15)
plt.xlabel('Wire diameter ($\mu m$)',fontsize=15)
plt.title('E-polarization',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.savefig('polarization fraction E_polar.png')
plt.show()


fig = plt.figure(figsize = (8,5))
key='1'
plt.plot(a,np.abs(F_H[key]['100'])*100,linestyle=lines[0],color=colors[0],label ='Wire space= 100mm (N=61)')
plt.plot(a,np.abs(F_H[key]['200'])*100,linestyle=lines[1],color=colors[0],label ='Wire space= 200mm (N=31)')
plt.plot(a,np.abs(F_H[key]['300'])*100,linestyle=lines[2],color=colors[0],label ='Wire space= 300mm (N=21)')
plt.plot(a,np.abs(F_H[key]['600'])*100,linestyle=lines[3],color=colors[0],label ='Wire space= 600mm (N=11)')
key = '3.33'
plt.plot(a,np.abs(F_H[key]['100'])*100,linestyle=lines[0],color=colors[1],)#label ='Wire space= 100mm (N=61)')
plt.plot(a,np.abs(F_H[key]['200'])*100,linestyle=lines[1],color=colors[1],)#label ='Wire space= 200mm (N=31)')
plt.plot(a,np.abs(F_H[key]['300'])*100,linestyle=lines[2],color=colors[1],)#label ='Wire space= 300mm (N=21)')
plt.plot(a,np.abs(F_H[key]['600'])*100,linestyle=lines[3],color=colors[1],)#label ='Wire space= 600mm (N=11)')

plt.legend(fontsize= 10)
#plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.ylabel('Scatter Fraction (%)',fontsize=15)
plt.xlabel('Wire diameter ($\mu m$)',fontsize=15)
plt.title('H-polarization',fontsize=16)
plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.savefig('polarization fraction H_polar.png')
plt.show()

# %%
(sigma_E(3.33,100/1000/2,Phi)*d_p).sum()/600*5/10
# Out:
# 0.0031922206439373934

# %%
fig = plt.figure(figsize = (8,5))
lines=['-','--',':','-.']
colors = ['k','blue','orange']

key='1'
plt.plot(a,np.abs(F_E[key]['100'])*100,linestyle=lines[0],color=colors[0],label ='$\lambda=$1mm')

key = '3.33'
plt.plot(a,np.abs(F_E[key]['100'])*100,linestyle=lines[0],color=colors[1],label ='$\lambda=$3.33mm')

plt.legend(fontsize=15)
#plt.legend(loc="upper left", bbox_to_anchor=(1, 1),fontsize=15)
plt.ylabel('Scatter Fraction (%)',fontsize=15)
plt.xlabel('Wire diameter ($\mu m$)',fontsize=15)
plt.title('E-polarization',fontsize=16)
#plt.grid(which ='both',axis='both')
plt.xlim([a[0],a[-1]])
plt.savefig('polarization fraction E_polar_lambda.png')
plt.show()

# %%
x = np.ones((5,10))
x.sum(axis=1)
# Out:
# array([10., 10., 10., 10., 10.])

# %%
Lambda = 3.33
L=600
K= 2*np.pi/Lambda
a = 10/2#0.127/2
Phi = np.linspace(0,2*np.pi,1001)
dPhi = Phi[1]-Phi[0]
beam = np.array([])
for asize in [0.1/2,1/2]:#[0.1/2, 0.5/2, 1/2, 5/2, 10/2]:
    beam  = np.append(beam,E_polar_co(Lambda,asize,Phi))
beam = np.array(beam).reshape(-1,1001)
print((sigma_E(Lambda,a,Phi)*dPhi).sum()/2/np.pi,4*a)
print(np.abs(beam)**2)
# Out:
# 5.954643060783623 20.0
# [[0.27489465 0.27489488 0.2748956  ... 0.2748956  0.27489488 0.27489465]
#  [0.91103699 0.91103566 0.91103166 ... 0.91103166 0.91103566 0.91103699]]

# %%
n=0
for asize in [0.1/2,1/2]:#[0.1/2, 0.5/2, 1/2, 5/2, 10/2]:
    plt.plot(Phi*180/np.pi, np.abs(beam[n,:]),label = 'Wire size:'+str(asize*2)+' mm')
    n+=1
plt.xlim([0,180])
plt.legend()
plt.ylabel('Scatter coefficient')
plt.xlabel('scatter angle (degrees)')
plt.savefig('scatter coefficient.png')
plt.show()

# %%
Lambda = 3.33
L=100
K= 2*np.pi/Lambda
a = 0.127/2#0.127/2
Phi = np.linspace(0,2*np.pi,1001)
dPhi = Phi[1]-Phi[0]
beam = np.array([])

beam  = E_polar_co(Lambda,asize,Phi)
print((sigma_E(Lambda,a,Phi)*dPhi).sum()/2/np.pi,4*a)
print(np.abs(beam)**2)
# Out:
# 0.7024598951052066 0.254
# [0.30977837 0.30977748 0.30977481 ... 0.30977481 0.30977748 0.30977837]

# %%
plt.plot(Phi*180/np.pi,(np.abs(beam)**2)/L)
plt.show()
#plt.xlim([0,180])
print(a)
sigma = sigma_E(Lambda,a,Phi)
plt.plot(Phi*180/np.pi,sigma)
plt.xlabel('Angle / degrees')
plt.ylabel('scattering width $\sigma$ / mm')
plt.savefig('scattering width.png')
plt.show()

plt.plot(Phi*180/np.pi,sigma/L*100)
plt.ylabel('Scattered Fraction $\sigma/ L, L=600mm$ (%)')
plt.xlabel('Angle / degrees')
plt.savefig('scattering fraction.png')
plt.show()

plt.plot(Phi*180/np.pi,np.log10(sigma/L)*10)
plt.show()
# Out:
# 0.0635

# %%
Lambda = 3.33
L=12.6
K= 2*np.pi/Lambda
a = 0.025/2
#Phi = np.linspace(0,np.pi,1001)
Phi = np.linspace(0,np.pi,1001)
beam  = E_polar_co(Lambda,a,Phi)
print((sigma_E(1,0.1/2,Phi)*np.pi/1000).sum()*2,4*a)
print(np.abs(beam)**2)

plt.plot(Phi*180/np.pi,(np.abs(beam)**2)/L)
plt.show()
#plt.xlim([0,180])
print(a)
sigma = sigma_E(Lambda,a,Phi)
plt.plot(Phi*180/np.pi,sigma/L)
plt.show()
# Out:
# 2.493125631071703 0.05
# [0.04766845 0.04766845 0.04766845 ... 0.04807948 0.04807948 0.04807949]
# 0.0125

# %%
0.023*2*np.pi*10
# Out:
# 1.4451326206513049
